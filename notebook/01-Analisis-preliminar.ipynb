# %%
import pandas as pd

# %%
movies = pd.read_csv("../data/output/dataset_final.csv")

# %%
movies.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45094 entries, 0 to 45093
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   adult                 45094 non-null  bool
#  1   budget                45094 non-null  int64
#  2   imdb_id               45094 non-null  str
#  3   original_language     45083 non-null  str
#  4   original_title        45094 non-null  str
#  5   overview              44150 non-null  str
#  6   popularity            45091 non-null  float64
#  7   release_date          45019 non-null  str
#  8   revenue               45091 non-null  float64
#  9   runtime               44836 non-null  float64
#  10  status                45013 non-null  str
#  11  tagline               20308 non-null  str
#  12  title                 45091 non-null  str
#  13  video                 45091 non-null  object
#  14  vote_average          45091 non-null  float64
# ...

# %%
print(movies.duplicated().sum())
# Out:
# 20

# %%
movies = movies.drop_duplicates()

# %%
import numpy as np

# %%
movies.replace("unknown", np.nan, inplace=True)
# Out:
#        adult    budget    imdb_id original_language  \
# 0      False  30000000  tt0114709                en
# 1      False  65000000  tt0113497                en
# 2      False         0  tt0113228                en
# 3      False  16000000  tt0114885                en
# 4      False         0  tt0113041                en
# ...      ...       ...        ...               ...
# 45089  False         0  tt6209470                fa
# 45090  False         0  tt2028550                tl
# 45091  False         0  tt0303758                en
# 45092  False         0  tt0008536                en
# 45093  False         0  tt6980792                en
#
#                     original_title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 45089                      رگ خواب
# 45090          Siglo ng Pagluluwal
# ...
